# %%
from ntscraper import Nitter

scraper = Nitter(instances=["http://localhost:8080"], log_level=1, skip_instance_check=False)
# Out:
# Testing instances:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing instances: 100%|██████████| 1/1 [00:04<00:00,  4.05s/it]

# %%
from ntscraper import Nitter

scraper = Nitter(log_level=1, skip_instance_check=False)
tweet = scraper.get_tweet_by_id("x", "1826317783430303888")
# Out:
# Testing instances: 100%|██████████| 8/8 [00:04<00:00,  1.71it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       1 from ntscraper import Nitter
#       3 scraper = Nitter(log_level=1, skip_instance_check=False)
# ----> 4 tweet = scraper.get_tweet_by_id("x", "1826317783430303888")
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:871, in Nitter.get_tweet_by_id(self, username, tweet_id, instance, max_retries)
#     869 else:
#     870     if not self.working_instances:
# --> 871         raise ValueError("No working instances available.")
#     872     self.instance = self.get_random_instance()
#     874 endpoint = f"/{username}/status/{tweet_id}"
#
# ValueError: No working instances available.

# %%
scraper.get_tweets("elonmusk")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 scraper.get_tweets("elonmusk")
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:926, in Nitter.get_tweets(self, terms, mode, number, since, until, near, language, to, replies, filters, exclude, max_retries, instance)
#     923 if type(terms) == str:
#     924     term = terms.strip()
# --> 926     return self._search(
#     927         term,
#     928         mode,
#     929         number,
#     930         since,
#     931         until,
#     932         near,
#     933         language,
#     934         to,
#     935         replies,
#     936         filters,
#     937         exclude,
#     938         max_retries,
#     939         instance,
#     940     )
#     941 elif len(terms) == 1:
#     942     term = terms[0].strip()
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:725, in Nitter._search(self, term, mode, number, since, until, near, language, to, replies, filters, exclude, max_retries, instance)
#     722 else:
#     723     raise ValueError("Invalid mode. Use 'term', 'hashtag', or 'user'.")
# --> 725 self._initialize_session(instance)
#     727 if language:
#     728     endpoint += f"+lang%3A{language}"
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:93, in Nitter._initialize_session(self, instance)
#      91     if self.skip_instance_check:
#      92         raise ValueError("No instance specified and instance check skipped")
# ---> 93     self.instance = self.get_random_instance()
#      94     logging.info(
#      95         f"No instance specified, using random instance {self.instance}"
#      96     )
#      97 else:
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:855, in Nitter.get_random_instance(self)
#     849 def get_random_instance(self):
#     850     """
#     851     Get a random Nitter instance
#     852
#     853     :return: URL of random Nitter instance
#     854     """
# --> 855     return random.choice(self.working_instances)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\random.py:373, in Random.choice(self, seq)
#     370 # As an accommodation for NumPy, we don't use "if not seq"
#     371 # because bool(numpy.array()) raises a ValueError.
#     372 if not len(seq):
# --> 373     raise IndexError('Cannot choose from an empty sequence')
#     374 return seq[self._randbelow(len(seq))]
#
# IndexError: Cannot choose from an empty sequence

# %%
github_hash_tweets = scraper.get_tweets("github", mode='hashtag')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 github_hash_tweets = scraper.get_tweets("github", mode='hashtag')
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:926, in Nitter.get_tweets(self, terms, mode, number, since, until, near, language, to, replies, filters, exclude, max_retries, instance)
#     923 if type(terms) == str:
#     924     term = terms.strip()
# --> 926     return self._search(
#     927         term,
#     928         mode,
#     929         number,
#     930         since,
#     931         until,
#     932         near,
#     933         language,
#     934         to,
#     935         replies,
#     936         filters,
#     937         exclude,
#     938         max_retries,
#     939         instance,
#     940     )
#     941 elif len(terms) == 1:
#     942     term = terms[0].strip()
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:725, in Nitter._search(self, term, mode, number, since, until, near, language, to, replies, filters, exclude, max_retries, instance)
#     722 else:
#     723     raise ValueError("Invalid mode. Use 'term', 'hashtag', or 'user'.")
# --> 725 self._initialize_session(instance)
#     727 if language:
#     728     endpoint += f"+lang%3A{language}"
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:93, in Nitter._initialize_session(self, instance)
#      91     if self.skip_instance_check:
#      92         raise ValueError("No instance specified and instance check skipped")
# ---> 93     self.instance = self.get_random_instance()
#      94     logging.info(
#      95         f"No instance specified, using random instance {self.instance}"
#      96     )
#      97 else:
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:855, in Nitter.get_random_instance(self)
#     849 def get_random_instance(self):
#     850     """
#     851     Get a random Nitter instance
#     852
#     853     :return: URL of random Nitter instance
#     854     """
# --> 855     return random.choice(self.working_instances)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\random.py:373, in Random.choice(self, seq)
#     370 # As an accommodation for NumPy, we don't use "if not seq"
#     371 # because bool(numpy.array()) raises a ValueError.
#     372 if not len(seq):
# --> 373     raise IndexError('Cannot choose from an empty sequence')
#     374 return seq[self._randbelow(len(seq))]
#
# IndexError: Cannot choose from an empty sequence

# %%
bezos_information = scraper.get_profile_info("JeffBezos")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 bezos_information = scraper.get_profile_info("JeffBezos")
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:1157, in Nitter.get_profile_info(self, username, max_retries, instance, mode)
#    1155 if isinstance(username, str):
#    1156     username = username.strip()
# -> 1157     profile_info = self._profile_info(username, max_retries, instance)
#    1158     if profile_info and mode == 'detail':
#    1159         profile_info["following_list"] = _get_follow_list(f"/{username}/following")
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:997, in Nitter._profile_info(self, username, max_retries, instance)
#     988 def _profile_info(self, username, max_retries, instance):
#     989     """
#     990     Gets the profile information for a user.
#     991
#    (...)    995     :return: dictionary of the profile's information
#     996     """
# --> 997     self._initialize_session(instance)
#     998     username = sub(r"[^A-Za-z0-9_+-:]", "", username)
#     999     soup = self._get_page(f"/{username}", max_retries)
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:93, in Nitter._initialize_session(self, instance)
#      91     if self.skip_instance_check:
#      92         raise ValueError("No instance specified and instance check skipped")
# ---> 93     self.instance = self.get_random_instance()
#      94     logging.info(
#      95         f"No instance specified, using random instance {self.instance}"
#      96     )
#      97 else:
#
# File c:\Users\rajesh.hugar\PycharmProjects\Twitter_Scraper_(By_Tweet_ID)\.venv\Lib\site-packages\ntscraper\nitter.py:855, in Nitter.get_random_instance(self)
#     849 def get_random_instance(self):
#     850     """
#     851     Get a random Nitter instance
#     852
#     853     :return: URL of random Nitter instance
#     854     """
# --> 855     return random.choice(self.working_instances)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\random.py:373, in Random.choice(self, seq)
#     370 # As an accommodation for NumPy, we don't use "if not seq"
#     371 # because bool(numpy.array()) raises a ValueError.
#     372 if not len(seq):
# --> 373     raise IndexError('Cannot choose from an empty sequence')
#     374 return seq[self._randbelow(len(seq))]
#
# IndexError: Cannot choose from an empty sequence
